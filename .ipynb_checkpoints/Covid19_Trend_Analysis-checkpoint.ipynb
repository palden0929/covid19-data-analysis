# %% [markdown]
# # COVID 19 Deaths Analysis

# %% [markdown]
# In This project we go over the trends and analyze the Covid 19 dataset.

# %% [markdown]
# ### 1. Loading and Exploring the Dataset

# %%
#Importing the necessary modules for data analyis
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#Loading the csv file
#parse_dates to convert the date column to date datetime objects
covid = pd.read_csv("Covid_Dataset.csv",parse_dates=['date'])

#Checking the first 5 rows
covid.head(5)
# Out:
#        country       date  total_cases  new_cases  new_cases_smoothed  \
# 0  Afghanistan 2020-01-01          NaN        NaN                 NaN
# 1  Afghanistan 2020-01-02          NaN        NaN                 NaN
# 2  Afghanistan 2020-01-03          NaN        NaN                 NaN
# 3  Afghanistan 2020-01-04          0.0        0.0                 NaN
# 4  Afghanistan 2020-01-05          0.0        0.0                 NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      0.0                    0.0
# 4                      0.0                    0.0
#
#    new_cases_smoothed_per_million  total_deaths  new_deaths  ...  population  \
# 0                             NaN           NaN         NaN  ...  40578847.0
# 1                             NaN           NaN         NaN  ...  40578847.0
# 2                             NaN           NaN         NaN  ...  40578847.0
# 3                             NaN           0.0         0.0  ...  40578847.0
# 4                             NaN           0.0         0.0  ...  40578847.0
#
#    population_density  median_age  life_expectancy  gdp_per_capita  \
# 0           62.215549   16.752001        65.616997     1516.273315
# 1           62.215549   16.752001        65.616997     1516.273315
# 2           62.215549   16.752001        65.616997     1516.273315
# 3           62.215549   16.752001        65.616997     1516.273315
# 4           62.215549   16.752001        65.616997     1516.273315
#
#    extreme_poverty  diabetes_prevalence  handwashing_facilities  \
# 0              NaN                 10.9               48.214695
# 1              NaN                 10.9               48.214695
# 2              NaN                 10.9               48.214695
# 3              NaN                 10.9               48.214695
# 4              NaN                 10.9               48.214695
#
#    hospital_beds_per_thousand  human_development_index
# 0                        0.39                      NaN
# 1                        0.39                      NaN
# 2                        0.39                      NaN
# 3                        0.39                      NaN
# 4                        0.39                      NaN
#
# [5 rows x 61 columns]

# %%
# Checking the count of the columns and rows
covid.shape
# Out:
# (113879, 61)

# %%
# Checking all the columns
covid.columns
# Out:
# Index(['country', 'date', 'total_cases', 'new_cases', 'new_cases_smoothed',
#        'total_cases_per_million', 'new_cases_per_million',
#        'new_cases_smoothed_per_million', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_deaths_per_million',
#        'new_deaths_per_million', 'new_deaths_smoothed_per_million',
#        'excess_mortality', 'excess_mortality_cumulative',
#        'excess_mortality_cumulative_absolute',
#        'excess_mortality_cumulative_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'icu_patients',
#        'icu_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'stringency_index',
#        'reproduction_rate', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million',
#        'new_people_vaccinated_smoothed',
#        'new_people_vaccinated_smoothed_per_hundred', 'code', 'continent',
#        'population', 'population_density', 'median_age', 'life_expectancy',
#        'gdp_per_capita', 'extreme_poverty', 'diabetes_prevalence',
#        'handwashing_facilities', 'hospital_beds_per_thousand',
#        'human_development_index'],
#       dtype='object')

# %%
# Getting only the columns that are needed for our data analysis
covid_subset = covid[[
       'country', 'date', 'total_cases', 'new_cases',
       'total_cases_per_million', 'new_cases_per_million',
       'total_deaths', 'new_deaths', 'total_deaths_per_million',
       'new_deaths_per_million', 'total_vaccinations',
       'people_vaccinated','total_vaccinations_per_hundred',
       'code', 'continent','population'
]]

# %%
# Checking missing values count
covid_subset.isna().sum()
# Out:
# country                               0
# date                                  0
# total_cases                        1484
# new_cases                          1497
# total_cases_per_million            1484
# new_cases_per_million              1497
# total_deaths                       1484
# new_deaths                         1494
# total_deaths_per_million           1484
# new_deaths_per_million             1494
# total_vaccinations                95114
# people_vaccinated                 97694
# total_vaccinations_per_hundred    95114
# code                               2075
# continent                          6223
# population                         2075
# dtype: int64

# %%
#Checking the datatypes of the columns
covid_subset.dtypes
# Out:
# country                                   object
# date                              datetime64[ns]
# total_cases                              float64
# new_cases                                float64
# total_cases_per_million                  float64
# new_cases_per_million                    float64
# total_deaths                             float64
# new_deaths                               float64
# total_deaths_per_million                 float64
# new_deaths_per_million                   float64
# total_vaccinations                       float64
# people_vaccinated                        float64
# total_vaccinations_per_hundred           float64
# code                                      object
# continent                                 object
# population                               float64
# dtype: object

# %%
# Checking the descriptive statistics as there are many numerical values
covid_subset.describe()
# Out:
#                                 date   total_cases     new_cases  \
# count                         113879  1.123950e+05  1.123820e+05
# mean   2022-10-29 18:20:42.560963584  8.097282e+06  6.400570e+03
# min              2020-01-01 00:00:00  0.000000e+00  0.000000e+00
# 25%              2021-05-26 00:00:00  9.106000e+03  0.000000e+00
# 50%              2022-10-25 00:00:00  7.143000e+04  0.000000e+00
# 75%              2024-04-02 00:00:00  9.940370e+05  6.400000e+01
# max              2025-12-31 00:00:00  3.021686e+08  7.213802e+06
# std                              NaN  3.695015e+07  9.038272e+04
#
#        total_cases_per_million  new_cases_per_million  total_deaths  \
# count            112395.000000          112382.000000  1.123950e+05
# mean             121305.519931              91.147835  6.664233e+04
# min                   0.000000               0.000000  0.000000e+00
# 25%                3037.639200               0.000000  8.400000e+01
# 50%               63801.445000               0.000000  7.720000e+02
# 75%              175187.030000               8.424857  1.302450e+04
# max              769806.800000           36330.008000  1.637891e+06
# std              160768.492842             614.021687  2.548282e+05
#
#           new_deaths  total_deaths_per_million  new_deaths_per_million  \
# count  112385.000000             112395.000000           112385.000000
# mean       43.786395                985.947175                0.658459
# min         0.000000                  0.000000                0.000000
# 25%         0.000000                 32.310177                0.000000
# 50%         0.000000                455.297800                0.000000
# 75%         0.000000               1645.535500                0.000000
# max     55431.000000               5679.282700              585.433500
# std       361.453785               1236.891532                4.352947
#
#        total_vaccinations  people_vaccinated  total_vaccinations_per_hundred  \
# count        1.876500e+04       1.618500e+04                    18765.000000
# mean         6.563327e+08       2.993864e+08                      128.597054
# min          0.000000e+00       0.000000e+00                        0.000000
# 25%          1.787387e+06       7.331490e+05                       47.486060
# 50%          1.828174e+07       8.737060e+06                      120.936560
# 75%          1.019011e+08       4.125734e+07                      208.941620
# max          9.180668e+09       3.699988e+09                      415.881440
# std          1.996905e+09       8.850006e+08                       95.263001
#
#          population
# count  1.118040e+05
# mean   1.585004e+08
# min    1.420200e+04
# 25%    4.027410e+05
# 50%    6.035104e+06
# 75%    2.620099e+07
# max    4.746330e+09
# std    6.862927e+08

# %%
# Checking for Outliers
covid_subset.hist(bins = 60, figsize = (20, 10))
# Out:
# array([[<Axes: title={'center': 'date'}>,
#         <Axes: title={'center': 'total_cases'}>,
#         <Axes: title={'center': 'new_cases'}>,
#         <Axes: title={'center': 'total_cases_per_million'}>],
#        [<Axes: title={'center': 'new_cases_per_million'}>,
#         <Axes: title={'center': 'total_deaths'}>,
#         <Axes: title={'center': 'new_deaths'}>,
#         <Axes: title={'center': 'total_deaths_per_million'}>],
#        [<Axes: title={'center': 'new_deaths_per_million'}>,
#         <Axes: title={'center': 'total_vaccinations'}>,
#         <Axes: title={'center': 'people_vaccinated'}>,
#         <Axes: title={'center': 'total_vaccinations_per_hundred'}>],
#        [<Axes: title={'center': 'population'}>, <Axes: >, <Axes: >,
#         <Axes: >]], dtype=object)

# %%
# Asia listed as country even though it is not
covid_subset.sort_values(by = 'population', ascending = False)
# Out:
#                  country       date  total_cases  new_cases  \
# 26491               Asia 2024-04-06  301397747.0      914.0
# 26298               Asia 2023-09-26  300629744.0      203.0
# 26328               Asia 2023-10-26  300724067.0      477.0
# 26327               Asia 2023-10-25  300723590.0      154.0
# 26326               Asia 2023-10-24  300723436.0      115.0
# ...                  ...        ...          ...        ...
# 29081   Asia excl. China 2025-09-04  202778164.0        3.0
# 29082   Asia excl. China 2025-09-05  202778164.0        0.0
# 29083   Asia excl. China 2025-09-06  202786869.0     8705.0
# 29084   Asia excl. China 2025-09-07  202786886.0       17.0
# 113878            Cyprus 2021-02-05      31891.0      116.0
#
#         total_cases_per_million  new_cases_per_million  total_deaths  \
# 26491                 63926.703               0.193860     1636859.0
# 26298                 63763.810               0.043056     1633555.0
# 26328                 63783.816               0.101172     1635187.0
# 26327                 63783.715               0.032664     1635186.0
# 26326                 63783.684               0.024392     1635184.0
# ...                         ...                    ...           ...
# 29081                 61642.950               0.000912     1515484.0
# 29082                 61642.950               0.000000     1515484.0
# 29083                 61645.594               2.646251     1515493.0
# 29084                 61645.600               0.005168     1515493.0
# 113878                33913.030             123.354910         211.0
#
#         new_deaths  total_deaths_per_million  new_deaths_per_million  \
# 26491          4.0                 347.17910                0.000848
# 26298          3.0                 346.47833                0.000636
# 26328          1.0                 346.82446                0.000212
# 26327          2.0                 346.82425                0.000424
# 26326          3.0                 346.82385                0.000636
# ...            ...                       ...                     ...
# 29081          0.0                 460.69507                0.000000
# 29082          0.0                 460.69507                0.000000
# 29083          9.0                 460.69780                0.002736
# 29084          0.0                 460.69780                0.000000
# 113878         5.0                 224.37833                5.317022
#
#         total_vaccinations  people_vaccinated  total_vaccinations_per_hundred  \
# 26491         9.180612e+09       3.699985e+09                       194.48833
# 26298         9.155899e+09       3.697913e+09                       193.96481
# 26328         9.164294e+09       3.698530e+09                       194.14265
# 26327         9.164057e+09       3.698507e+09                       194.13762
# 26326         9.163819e+09       3.698484e+09                       194.13258
# ...                    ...                ...                             ...
# 29081                  NaN                NaN                             NaN
# 29082                  NaN                NaN                             NaN
# 29083                  NaN                NaN                             NaN
# 29084                  NaN                NaN                             NaN
# 113878                 NaN                NaN                             NaN
#
#             code continent    population
# 26491   OWID_ASI       NaN  4.746330e+09
# 26298   OWID_ASI       NaN  4.746330e+09
# 26328   OWID_ASI       NaN  4.746330e+09
# 26327   OWID_ASI       NaN  4.746330e+09
# 26326   OWID_ASI       NaN  4.746330e+09
# ...          ...       ...           ...
# 29081        NaN       NaN           NaN
# 29082        NaN       NaN           NaN
# 29083        NaN       NaN           NaN
# 29084        NaN       NaN           NaN
# 113878       NaN       NaN           NaN
#
# [113879 rows x 16 columns]

# %%
# Checking what other continents are there
covid_subset["country"].value_counts()
# Out:
# country
# Bulgaria                           2093
# Canada                             2093
# Austria                            2093
# Australia                          2093
# Chile                              2093
# Croatia                            2093
# Belgium                            2093
# Colombia                           2093
# Belarus                            2081
# Bermuda                            2081
# Cape Verde                         2081
# Bhutan                             2081
# Bolivia                            2081
# Bosnia and Herzegovina             2081
# Brazil                             2081
# Brunei                             2081
# Barbados                           2081
# Belize                             2081
# Cuba                               2081
# Argentina                          2081
# Albania                            2081
# Algeria                            2081
# Andorra                            2081
# Bahamas                            2081
# Aruba                              2081
# Costa Rica                         2081
# Azerbaijan                         2081
# Armenia                            2078
# Antigua and Barbuda                2078
# Burkina Faso                       2077
# Chad                               2077
# Cameroon                           2077
# Cambodia                           2077
# Burundi                            2077
# Central African Republic           2077
# Afghanistan                        2077
# Congo                              2077
# Botswana                           2077
# Benin                              2077
# Bangladesh                         2077
# Bahrain                            2077
# Angola                             2077
# China                              2077
# Cook Islands                       2074
# Comoros                            2074
# Curacao                            2074
# Bonaire Sint Eustatius and Saba    2074
# Cayman Islands                     2074
# British Virgin Islands             2074
# Africa                             2074
# Asia excl. China                   2074
# Asia                               2074
# Anguilla                           2074
# American Samoa                     2074
# Cote d'Ivoire                      1146
# Cyprus                              402
# Name: count, dtype: int64

# %%
# Continents listed as countries hava NAN values in the continent column
asia = covid_subset[covid_subset["country"] == "Asia"]
asia
# Out:
#       country       date  total_cases  new_cases  total_cases_per_million  \
# 24937    Asia 2020-01-04          1.0        1.0                 0.000212
# 24938    Asia 2020-01-05          1.0        0.0                 0.000212
# 24939    Asia 2020-01-06          4.0        3.0                 0.000848
# 24940    Asia 2020-01-07          4.0        0.0                 0.000848
# 24941    Asia 2020-01-08          4.0        0.0                 0.000848
# ...       ...        ...          ...        ...                      ...
# 27006    Asia 2025-09-03  302159922.0        2.0             64088.363000
# 27007    Asia 2025-09-04  302159925.0        3.0             64088.363000
# 27008    Asia 2025-09-05  302159925.0        0.0             64088.363000
# 27009    Asia 2025-09-06  302168630.0     8705.0             64090.207000
# 27010    Asia 2025-09-07  302168647.0       17.0             64090.210000
#
#        new_cases_per_million  total_deaths  new_deaths  \
# 24937               0.000212           0.0         0.0
# 24938               0.000000           0.0         0.0
# 24939               0.000636           0.0         0.0
# 24940               0.000000           0.0         0.0
# 24941               0.000000           0.0         0.0
# ...                      ...           ...         ...
# 27006               0.000424     1637882.0         0.0
# 27007               0.000636     1637882.0         0.0
# 27008               0.000000     1637882.0         0.0
# 27009               1.846337     1637891.0         9.0
# 27010               0.003606     1637891.0         0.0
#
#        total_deaths_per_million  new_deaths_per_million  total_vaccinations  \
# 24937                    0.0000                0.000000                 NaN
# 24938                    0.0000                0.000000                 NaN
# 24939                    0.0000                0.000000                 NaN
# 24940                    0.0000                0.000000                 NaN
# 24941                    0.0000                0.000000                 NaN
# ...                         ...                     ...                 ...
# 27006                  347.3961                0.000000                 NaN
# 27007                  347.3961                0.000000                 NaN
# 27008                  347.3961                0.000000                 NaN
# 27009                  347.3980                0.001909                 NaN
# 27010                  347.3980                0.000000                 NaN
#
#        people_vaccinated  total_vaccinations_per_hundred      code continent  \
# 24937                NaN                             NaN  OWID_ASI       NaN
# 24938                NaN                             NaN  OWID_ASI       NaN
# 24939                NaN                             NaN  OWID_ASI       NaN
# 24940                NaN                             NaN  OWID_ASI       NaN
# 24941                NaN                             NaN  OWID_ASI       NaN
# ...                  ...                             ...       ...       ...
# 27006                NaN                             NaN  OWID_ASI       NaN
# 27007                NaN                             NaN  OWID_ASI       NaN
# 27008                NaN                             NaN  OWID_ASI       NaN
# 27009                NaN                             NaN  OWID_ASI       NaN
# 27010                NaN                             NaN  OWID_ASI       NaN
#
#          population
# 24937  4.746330e+09
# 24938  4.746330e+09
# 24939  4.746330e+09
# 24940  4.746330e+09
# 24941  4.746330e+09
# ...             ...
# 27006  4.746330e+09
# 27007  4.746330e+09
# 27008  4.746330e+09
# 27009  4.746330e+09
# 27010  4.746330e+09
#
# [2074 rows x 16 columns]

# %% [markdown]
# ### 2. Cleaning the Data

# %%
# Dealing with the continents listed as countries
invalid_countries = [
    'World', 'Asia', 'Europe', 'Africa', 'North America', 
    'South America', 'Oceania', 'European Union', 'International'
]

covid_subset = covid_subset[~covid_subset['country'].isin(invalid_countries)]
covid_subset = covid_subset[covid_subset['continent'].notna()]  # removes rows with no continent

# %%
# Removing tiny countries as well as they skew the data and are not important for our data analysis
covid_subset = covid_subset[covid_subset['population'] > 100000]  # remove microstates

# %%
# Checking the missing values left
covid_subset.isna().sum()
# Out:
# country                               0
# date                                  0
# total_cases                        1466
# new_cases                          1475
# total_cases_per_million            1466
# new_cases_per_million              1475
# total_deaths                       1466
# new_deaths                         1475
# total_deaths_per_million           1466
# new_deaths_per_million             1475
# total_vaccinations                73413
# people_vaccinated                 75975
# total_vaccinations_per_hundred    73413
# code                                  0
# continent                             0
# population                            0
# dtype: int64

# %%
log = ['total_cases', 'total_deaths', 'total_vaccinations', 'people_vaccinated', 'population']
for col in log:
    covid_subset[f'log_{col}'] = np.log1p(covid_subset[col])

# %%
covid_subset.hist(bins = 60, figsize = (20, 10))
# Out:
# array([[<Axes: title={'center': 'date'}>,
#         <Axes: title={'center': 'total_cases'}>,
#         <Axes: title={'center': 'new_cases'}>,
#         <Axes: title={'center': 'total_cases_per_million'}>],
#        [<Axes: title={'center': 'new_cases_per_million'}>,
#         <Axes: title={'center': 'total_deaths'}>,
#         <Axes: title={'center': 'new_deaths'}>,
#         <Axes: title={'center': 'total_deaths_per_million'}>],
#        [<Axes: title={'center': 'new_deaths_per_million'}>,
#         <Axes: title={'center': 'total_vaccinations'}>,
#         <Axes: title={'center': 'people_vaccinated'}>,
#         <Axes: title={'center': 'total_vaccinations_per_hundred'}>],
#        [<Axes: title={'center': 'population'}>,
#         <Axes: title={'center': 'log_total_cases'}>,
#         <Axes: title={'center': 'log_total_deaths'}>,
#         <Axes: title={'center': 'log_total_vaccinations'}>],
#        [<Axes: title={'center': 'log_people_vaccinated'}>,
#         <Axes: title={'center': 'log_population'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
covid_subset["country"].value_counts()
# Out:
# country
# Canada                             2093
# Croatia                            2093
# Belgium                            2093
# Austria                            2093
# Australia                          2093
# Chile                              2093
# Bulgaria                           2093
# Colombia                           2093
# Brazil                             2081
# Albania                            2081
# Belarus                            2081
# Bolivia                            2081
# Bhutan                             2081
# Brunei                             2081
# Bermuda                            2081
# Belize                             2081
# Cape Verde                         2081
# Bosnia and Herzegovina             2081
# Bahamas                            2081
# Azerbaijan                         2081
# Aruba                              2081
# Argentina                          2081
# Costa Rica                         2081
# Andorra                            2081
# Cuba                               2081
# Algeria                            2081
# Barbados                           2081
# Armenia                            2078
# Antigua and Barbuda                2078
# Cameroon                           2077
# Congo                              2077
# China                              2077
# Chad                               2077
# Central African Republic           2077
# Afghanistan                        2077
# Cambodia                           2077
# Burkina Faso                       2077
# Botswana                           2077
# Angola                             2077
# Benin                              2077
# Bangladesh                         2077
# Burundi                            2077
# Bahrain                            2077
# Anguilla                           2074
# Curacao                            2074
# American Samoa                     2074
# Comoros                            2074
# Cook Islands                       2074
# Bonaire Sint Eustatius and Saba    2074
# British Virgin Islands             2074
# Cayman Islands                     2074
# Cote d'Ivoire                      1146
# Cyprus                              401
# Name: count, dtype: int64
